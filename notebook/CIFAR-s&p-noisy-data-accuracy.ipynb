# %%
import sys
sys.path.append('../libml')
from summary_utils import show_noise_plot, print_summary_noise_table, show_noise_gap_plot

# %matplotlib inline

# %% [markdown]
# # S&P noisy dataset
# ## CIFAR-10

# %%
print('-'*30)
print('Salt and Pepper noise')
print('-'*30)
print_summary_noise_table(dataset='cifar10', mode='s&p', p=0.005)
print_summary_noise_table(dataset='cifar10', mode='s&p', p=0.01)
print_summary_noise_table(dataset='cifar10', mode='s&p', p=0.02)
# Out:
# ------------------------------
# Salt and Pepper noise
# ------------------------------
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 & $73.9\pm1.3$ & $77.3\pm1.0$ & $78.6\pm0.6$ & $78.3\pm0.6$ & $78.1\pm0.8$ & $77.9\pm0.7$ \tabularnewline
# \cline{2-8}
# & 5000 & $79.8\pm0.7$ & $81.9\pm0.4$ & $82.9\pm0.3$ & $82.9\pm0.2$ & $82.7\pm0.4$ & $82.8\pm0.3$ \tabularnewline
# \cline{2-8}
# & 25000 & $88.0\pm0.4$ & $88.4\pm0.8$ & $89.1\pm0.3$ & $89.4\pm0.2$ & $89.6\pm0.2$ & $89.5\pm0.2$ \tabularnewline
# \cline{2-8}
# & 50000 & $89.7\pm0.3$ & $89.5\pm0.8$ & $90.7\pm0.3$ & $90.5\pm0.2$ & $90.6\pm0.4$ & $90.6\pm0.2$ \tabularnewline
# \hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 & $69.5\pm1.8$ & $72.7\pm1.9$ & $75.0\pm1.1$ & $75.0\pm0.8$ & $74.8\pm1.0$ & $75.0\pm0.6$ \tabularnewline
# \cline{2-8}
# & 5000 & $75.2\pm1.2$ & $76.4\pm1.3$ & $79.5\pm0.6$ & $80.0\pm0.5$ & $79.5\pm0.7$ & $80.0\pm0.3$ \tabularnewline
# \cline{2-8}
# & 25000 & $83.2\pm1.1$ & $82.2\pm1.6$ & $85.0\pm0.8$ & $85.7\pm0.3$ & $86.3\pm0.3$ & $86.8\pm0.4$ \tabularnewline
# \cline{2-8}
# & 50000 & $83.9\pm1.1$ & $82.6\pm1.1$ & $86.6\pm0.7$ & $86.7\pm0.5$ & $87.4\pm0.5$ & $87.8\pm0.2$ \tabularnewline
# \hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 & $60.6\pm3.0$ & $63.7\pm2.6$ & $68.1\pm1.2$ & $67.9\pm0.7$ & $67.5\pm1.5$ & $67.7\pm1.2$ \tabularnewline
# \cline{2-8}
# & 5000 & $66.2\pm2.2$ & $65.7\pm3.1$ & $72.7\pm1.3$ & $73.1\pm1.2$ & $73.0\pm1.6$ & $73.1\pm0.8$ \tabularnewline
# \cline{2-8}
# & 25000 & $73.7\pm1.7$ & $71.1\pm2.8$ & $77.3\pm0.9$ & $78.7\pm0.7$ & $79.8\pm0.4$ & $80.5\pm0.8$ \tabularnewline
# \cline{2-8}
# & 50000 & $72.9\pm2.3$ & $70.3\pm1.6$ & $78.9\pm0.7$ & $79.5\pm0.7$ & $80.8\pm1.0$ & $81.5\pm0.4$ \tabularnewline
# \hline
# \end{tabular}

# %% [markdown]
# ## CIFAR-100

# %%
print('-'*30)
print('Salt and Pepper noise')
print('-'*30)
print_summary_noise_table(dataset='cifar100', mode='s&p', p=0.005)
print_summary_noise_table(dataset='cifar100', mode='s&p', p=0.01)
print_summary_noise_table(dataset='cifar100', mode='s&p', p=0.02)
# Out:
# ------------------------------
# Salt and Pepper noise
# ------------------------------
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 & $31.9\pm0.3$ & $36.8\pm0.7$ & $37.6\pm0.9$ & $38.0\pm0.5$ & $37.6\pm0.2$ & $37.7\pm0.6$ \tabularnewline
# \cline{2-8}
# & 5000 & $41.4\pm1.1$ & $45.5\pm0.6$ & $46.8\pm0.4$ & $46.7\pm0.7$ & $46.6\pm0.7$ & $46.3\pm0.6$ \tabularnewline
# \cline{2-8}
# & 25000 & $60.4\pm1.4$ & $60.2\pm0.6$ & $62.7\pm0.7$ & $62.7\pm0.8$ & $62.9\pm0.4$ & $63.1\pm0.2$ \tabularnewline
# \cline{2-8}
# & 50000 & $64.4\pm0.9$ & $63.7\pm1.3$ & $67.6\pm0.3$ & $67.7\pm0.4$ & $68.3\pm0.5$ & $68.7\pm0.3$ \tabularnewline
# \hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 & $29.2\pm0.3$ & $33.4\pm0.8$ & $35.0\pm1.0$ & $35.1\pm0.2$ & $34.6\pm0.3$ & $34.8\pm0.7$ \tabularnewline
# \cline{2-8}
# & 5000 & $37.0\pm1.0$ & $39.5\pm1.2$ & $41.9\pm1.2$ & $42.1\pm0.8$ & $42.5\pm0.7$ & $42.0\pm0.6$ \tabularnewline
# \cline{2-8}
# & 25000 & $51.1\pm2.0$ & $49.5\pm1.2$ & $54.5\pm1.0$ & $55.6\pm0.8$ & $56.0\pm0.4$ & $56.9\pm0.3$ \tabularnewline
# \cline{2-8}
# & 50000 & $51.8\pm1.7$ & $49.8\pm2.9$ & $57.8\pm1.0$ & $59.4\pm0.9$ & $60.7\pm0.8$ & $62.0\pm0.5$ \tabularnewline
# \hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 & $23.7\pm0.5$ & $25.7\pm1.1$ & $28.9\pm0.8$ & $28.9\pm0.5$ & $28.6\pm0.5$ & $28.5\pm0.8$ \tabularnewline
# \cline{2-8}
# & 5000 & $27.1\pm1.5$ & $27.6\pm2.4$ & $32.5\pm2.1$ & $32.4\pm0.7$ & $33.4\pm1.4$ & $33.0\pm0.9$ \tabularnewline
# \cline{2-8}
# & 25000 & $33.7\pm2.8$ & $31.5\pm1.6$ & $38.3\pm2.2$ & $40.7\pm0.9$ & $41.1\pm1.0$ & $42.0\pm0.5$ \tabularnewline
# \cline{2-8}
# & 50000 & $31.5\pm2.1$ & $29.4\pm4.1$ & $40.0\pm1.3$ & $41.9\pm1.4$ & $44.1\pm0.9$ & $46.4\pm1.1$ \tabularnewline
# \hline
# \end{tabular}

# %% [markdown]
# # Visualize results
# ## CIFAR-10

# %%
print('-'*30)
print('Salt and Pepper noise')
print('-'*30)
show_noise_plot(dataset='cifar10', split='test', mode='s&p', p=0.005)
show_noise_plot(dataset='cifar10', split='test', mode='s&p', p=0.01)
show_noise_plot(dataset='cifar10', split='test', mode='s&p', p=0.02)
# Out:
# ------------------------------
# Salt and Pepper noise
# ------------------------------

# %% [markdown]
# ## CIFAR-100

# %%
print('-'*30)
print('Salt and Pepper noise')
print('-'*30)
show_noise_plot(dataset='cifar100', split='test', mode='s&p', p=0.005)
show_noise_plot(dataset='cifar100', split='test', mode='s&p', p=0.01)
show_noise_plot(dataset='cifar100', split='test', mode='s&p', p=0.02)
# Out:
# ------------------------------
# Salt and Pepper noise
# ------------------------------
