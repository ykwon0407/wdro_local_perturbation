# %%
import sys
sys.path.append('../libml')
from summary_utils import show_summary_plot, print_summary_table

import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # Clean data result
# ## For the paper version, we need editting somehow.

# %%
print_summary_table(dataset='cifar10')
print_summary_table(dataset='cifar100')
# Out:
# \begin{tabular}{cccccccccc}
# \hline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 &$77.3\pm0.9$ &$81.5\pm0.3$ &$81.3\pm0.4$ &$81.2\pm0.6$ &$80.8\pm0.7$ &$80.4\pm0.6$ \tabularnewline
# \cline{2-10}
# & 5000 &$83.5\pm0.4$ &$86.6\pm0.2$ &$86.4\pm0.2$ &$86.2\pm0.2$ &$85.6\pm0.5$ &$85.2\pm0.3$ \tabularnewline
# \cline{2-10}
# & 25000 &$92.2\pm0.2$ &$93.3\pm0.2$ &$93.0\pm0.2$ &$92.6\pm0.2$ &$92.3\pm0.1$ &$91.7\pm0.2$ \tabularnewline
# \cline{2-10}
# & 50000 &$94.1\pm0.1$ &$94.7\pm0.2$ &$94.4\pm0.1$ &$93.8\pm0.1$ &$93.4\pm0.2$ &$92.9\pm0.2$ \tabularnewline
# \\hline
# \end{tabular}
# \begin{tabular}{cccccccccc}
# \hline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 &$33.8\pm0.8$ &$39.0\pm0.6$ &$39.3\pm0.8$ &$39.5\pm0.6$ &$39.5\pm0.3$ &$39.4\pm0.7$ \tabularnewline
# \cline{2-10}
# & 5000 &$45.1\pm1.0$ &$50.0\pm0.2$ &$50.1\pm0.3$ &$49.7\pm0.4$ &$49.5\pm0.4$ &$48.9\pm0.6$ \tabularnewline
# \cline{2-10}
# ...

# %% [markdown]
# # Visualize Table 1

# %%
show_summary_plot(dataset='cifar10')
show_summary_plot(dataset='cifar100')
