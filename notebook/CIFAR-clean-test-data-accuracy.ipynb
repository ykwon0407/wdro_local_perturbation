# %%
import sys
sys.path.append('../libml')
from summary_utils import show_summary_plot, print_summary_table, print_t_test_results

import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # Clean data experiment
# ## For the paper version, we edit a table style.

# %%
print_summary_table(dataset='cifar10')
print_summary_table(dataset='cifar100')
# Out:
# \begin{tabular}{cccccccc}
# \hline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 &$77.3\pm0.8$ &$81.4\pm0.5$ &$77.1\pm0.7$ &$80.8\pm0.7$ \tabularnewline
# & 5000 &$83.3\pm0.4$ &$86.7\pm0.2$ &$83.0\pm0.3$ &$85.6\pm0.3$ \tabularnewline
# & 25000 &$92.2\pm0.2$ &$93.3\pm0.1$ &$91.4\pm0.1$ &$92.4\pm0.1$ \tabularnewline
# & 50000 &$94.1\pm0.1$ &$94.8\pm0.2$ &$93.1\pm0.1$ &$93.5\pm0.2$ \tab\hline
# \end{tabular}
# \begin{tabular}{cccccccc}
# \hline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 &$33.8\pm1.0$ &$38.9\pm0.6$ &$34.6\pm1.7$ &$39.4\pm0.2$ \tabularnewline
# & 5000 &$45.2\pm0.9$ &$nan\pmnan$ &$43.7\pm0.7$ &$49.5\pm0.4$ \tabularnewline
# & 25000 &$67.8\pm0.2$ &$69.3\pm0.3$ &$66.6\pm0.3$ &$68.2\pm0.3$ \tabularnewline
# & 50000 &$74.4\pm0.2$ &$75.2\pm0.2$ &$73.5\pm0.3$ &$73.8\pm0.3$ \tab\hline
# \end{tabular}

# %%
print_t_test_results(dataset='cifar10')
print_t_test_results(dataset='cifar100')
# Out:
# ----------
# dataset: cifar10
# sample: 2500
# ----------
# erm / p-value:  9.711608210336744e-05 / is equivalnet?  False
# mixup / p-value:  1.0 / is equivalnet?  True
# erm_0.004 / p-value:  1.7306258663148704e-05 / is equivalnet?  False
# l2_0.004 / p-value:  0.1479503485479032 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 5000
# ----------
# erm / p-value:  1.918885809548941e-06 / is equivalnet?  False
# mixup / p-value:  1.0 / is equivalnet?  True
# erm_0.004 / p-value:  6.253490308066991e-07 / is equivalnet?  False
# l2_0.004 / p-value:  0.0011403664661311483 / is equivalnet?  False
# ----------
# dataset: cifar10
# sample: 25000
# ----------
# erm / p-value:  3.7663577535793413e-06 / is equivalnet?  False
# mixup / p-value:  1.0 / is equivalnet?  True
# erm_0.004 / p-value:  1.4816010221804112e-08 / is equivalnet?  False
# l2_0.004 / p-value:  5.612994017898426e-06 / is equivalnet?  False
# ----------
# dataset: cifar10
# sample: 50000
# ----------
# ...

# %% [markdown]
# # Visualize the clean data experiment

# %%
show_summary_plot(dataset='cifar10')
show_summary_plot(dataset='cifar100')
