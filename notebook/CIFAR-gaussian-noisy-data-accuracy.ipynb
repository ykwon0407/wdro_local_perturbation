# %%
import sys
sys.path.append('../libml')
from summary_utils import show_noise_plot, print_summary_noise_table, show_noise_gap_plot

# %matplotlib inline

# %% [markdown]
# # Gaussian noise
# ## CIFAR-10

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
print_summary_noise_table(dataset='cifar10', mode='gaussian', var=0.005)
print_summary_noise_table(dataset='cifar10', mode='gaussian', var=0.01)
print_summary_noise_table(dataset='cifar10', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 & $68.2\pm1.4$ & $70.1\pm1.4$ & $70.1\pm2.4$ & $71.3\pm1.9$ & $72.4\pm1.5$ & $73.8\pm1.2$ \tabularnewline
# \cline{2-8}
# & 5000 & $71.0\pm1.8$ & $76.8\pm0.7$ & $77.7\pm0.5$ & $78.7\pm0.8$ & $79.0\pm0.6$ & $80.2\pm0.7$ \tabularnewline
# \cline{2-8}
# & 25000 & $78.7\pm0.4$ & $84.1\pm1.2$ & $85.9\pm0.7$ & $86.3\pm0.6$ & $87.6\pm0.3$ & $88.1\pm0.3$ \tabularnewline
# \cline{2-8}
# & 50000 & $79.8\pm1.3$ & $85.1\pm0.6$ & $87.2\pm0.4$ & $87.7\pm0.5$ & $88.5\pm0.3$ & $89.1\pm0.2$ \tabularnewline
# \hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# ...

# %% [markdown]
# ## CIFAR-100

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
print_summary_noise_table(dataset='cifar100', mode='gaussian', var=0.005)
print_summary_noise_table(dataset='cifar100', mode='gaussian', var=0.01)
print_summary_noise_table(dataset='cifar100', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 & $29.2\pm0.7$ & $27.6\pm1.7$ & $29.5\pm1.6$ & $30.8\pm1.4$ & $32.1\pm1.0$ & $33.4\pm1.1$ \tabularnewline
# \cline{2-8}
# & 5000 & $35.0\pm1.8$ & $34.7\pm1.8$ & $37.6\pm1.3$ & $39.9\pm0.8$ & $41.4\pm1.3$ & $42.2\pm0.9$ \tabularnewline
# \cline{2-8}
# & 25000 & $43.1\pm1.4$ & $48.3\pm1.1$ & $54.3\pm0.6$ & $56.5\pm1.1$ & $58.5\pm0.4$ & $59.8\pm0.4$ \tabularnewline
# \cline{2-8}
# & 50000 & $46.0\pm0.9$ & $50.6\pm1.4$ & $59.3\pm0.8$ & $61.1\pm0.6$ & $63.5\pm0.6$ & $65.2\pm0.4$ \tabularnewline
# \hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# ...

# %% [markdown]
# # Visualize results
# ## CIFAR-10

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
show_noise_plot(dataset='cifar10', split='test', mode='gaussian', var=0.005)
show_noise_plot(dataset='cifar10', split='test', mode='gaussian', var=0.01)
show_noise_plot(dataset='cifar10', split='test', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------

# %% [markdown]
# ## CIFAR-100

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
show_noise_plot(dataset='cifar100', split='test', mode='gaussian', var=0.005)
show_noise_plot(dataset='cifar100', split='test', mode='gaussian', var=0.01)
show_noise_plot(dataset='cifar100', split='test', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------

# %% [markdown]
# # Visualize degradation gap
# ## CIFAR-10

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
show_noise_gap_plot(dataset='cifar10', split='test', mode='gaussian', var=0.005)
show_noise_gap_plot(dataset='cifar10', split='test', mode='gaussian', var=0.01)
show_noise_gap_plot(dataset='cifar10', split='test', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------

# %% [markdown]
# ## CIFAR-100

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
show_noise_gap_plot(dataset='cifar100', split='test', mode='gaussian', var=0.005)
show_noise_gap_plot(dataset='cifar100', split='test', mode='gaussian', var=0.01)
show_noise_gap_plot(dataset='cifar100', split='test', mode='gaussian', var=0.02)
print('-'*30)
print('Salt and Pepper noise')
print('-'*30)
show_noise_gap_plot(dataset='cifar100', split='test', mode='s&p', p=0.005)
show_noise_gap_plot(dataset='cifar100', split='test', mode='s&p', p=0.01)
show_noise_gap_plot(dataset='cifar100', split='test', mode='s&p', p=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------
# ------------------------------
# Salt and Pepper noise
# ------------------------------

# %%
# print('-'*30)
# print('Gaussian')
# print('-'*30)
# show_noise_gap_plot(data=data, split='train', mode='gaussian', var=0.005)
# show_noise_gap_plot(data=data, split='train', mode='gaussian', var=0.01)
# show_noise_gap_plot(data=data, split='train', mode='gaussian', var=0.02)
# print('-'*30)
# print('Salt and Pepper noise')
# print('-'*30)
# show_noise_gap_plot(data=data, split='train', mode='s&p', p=0.005)
# show_noise_gap_plot(data=data, split='train', mode='s&p', p=0.01)
# show_noise_gap_plot(data=data, split='train', mode='s&p', p=0.02)
