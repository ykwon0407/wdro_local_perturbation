# %%
import sys
sys.path.append('../libml')
from summary_utils import show_noise_plot, print_summary_noise_table, show_noise_gap_plot, print_t_test_noise_results

import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# # Gaussian noise
# ## CIFAR-10

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
print_summary_noise_table(dataset='cifar10', mode='gaussian', var=0.005)
print_summary_noise_table(dataset='cifar10', mode='gaussian', var=0.01)
print_summary_noise_table(dataset='cifar10', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 & $68.2\pm1.4$ & $70.1\pm1.4$ & $70.1\pm2.4$ & $71.3\pm1.9$ & $72.4\pm1.5$ & $73.8\pm1.2$ \tabularnewline
# & 5000 & $71.0\pm1.8$ & $76.8\pm0.7$ & $77.7\pm0.5$ & $78.7\pm0.8$ & $79.0\pm0.6$ & $80.2\pm0.7$ \tabularnewline
# & 25000 & $78.7\pm0.4$ & $84.1\pm1.2$ & $85.9\pm0.7$ & $86.3\pm0.6$ & $87.6\pm0.3$ & $88.1\pm0.3$ \tabularnewline
# & 50000 & $79.8\pm1.3$ & $85.1\pm0.6$ & $87.2\pm0.4$ & $87.7\pm0.5$ & $88.5\pm0.3$ & $89.1\pm0.2$ \tab\hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 & $59.9\pm2.6$ & $62.7\pm2.5$ & $61.7\pm4.1$ & $62.6\pm3.1$ & $63.9\pm2.5$ & $66.4\pm2.2$ \tabularnewline
# & 5000 & $60.2\pm2.9$ & $69.3\pm2.1$ & $70.1\pm1.4$ & $71.7\pm1.8$ & $71.8\pm0.5$ & $73.6\pm1.2$ \tabularnewline
# & 25000 & $66.0\pm1.0$ & $75.1\pm3.0$ & $76.6\pm2.7$ & $78.0\pm1.6$ & $80.1\pm1.1$ & $82.3\pm0.7$ \tabularnewline
# & 50000 & $65.6\pm2.1$ & $75.6\pm1.3$ & $77.9\pm1.5$ & $78.8\pm1.5$ & $81.1\pm0.7$ & $82.8\pm0.3$ \tab\hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar10}
# & 2500 & $47.1\pm5.1$ & $52.5\pm4.0$ & $50.4\pm6.2$ & $50.9\pm4.8$ & $51.3\pm4.7$ & $53.9\pm4.6$ \tabularnewline
# & 5000 & $45.8\pm3.7$ & $57.7\pm3.7$ & $58.3\pm3.3$ & $60.2\pm3.5$ & $59.7\pm1.8$ & $61.1\pm2.3$ \tabularnewline
# & 25000 & $47.3\pm2.5$ & $59.9\pm7.1$ & $59.9\pm5.2$ & $63.0\pm4.6$ & $65.9\pm2.2$ & $70.5\pm2.2$ \tabularnewline
# & 50000 & $44.9\pm2.6$ & $59.7\pm2.6$ & $61.9\pm4.0$ & $62.2\pm3.7$ & $66.3\pm2.1$ & $69.0\pm1.1$ \tab\hline
# \end{tabular}

# %%
print_t_test_noise_results(dataset='cifar10', mode='gaussian', var=0.005)
print_t_test_noise_results(dataset='cifar10', mode='gaussian', var=0.01)
print_t_test_noise_results(dataset='cifar10', mode='gaussian', var=0.02)
# Out:
# ----------
# dataset: cifar10
# sample: 2500
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.005, 'seed': None}
# ----------
# ERM / p-value:  0.00016881563514678985 / is equivalnet?  False
# Mixup / p-value:  0.0019745394188844987 / is equivalnet?  False
# l2_0.001 / p-value:  0.02471400436265109 / is equivalnet?  False
# l2_0.002 / p-value:  0.04736570554616117 / is equivalnet?  False
# l2_0.004 / p-value:  0.14661381033157808 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 5000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.005, 'seed': None}
# ----------
# ERM / p-value:  0.00012771175639223858 / is equivalnet?  False
# Mixup / p-value:  5.31670311080968e-05 / is equivalnet?  False
# l2_0.001 / p-value:  0.0001918728415662618 / is equivalnet?  False
# l2_0.002 / p-value:  0.011598143288803937 / is equivalnet?  False
# l2_0.004 / p-value:  0.011262043791725814 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 25000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.005, 'seed': None}
# ----------
# ERM / p-value:  1.994747268089114e-10 / is equivalnet?  False
# Mixup / p-value:  0.001104574837309816 / is equivalnet?  False
# l2_0.001 / p-value:  0.0005175387839108199 / is equivalnet?  False
# l2_0.002 / p-value:  0.001167913881879318 / is equivalnet?  False
# l2_0.004 / p-value:  0.025322344646501706 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 50000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.005, 'seed': None}
# ----------
# ERM / p-value:  7.256834341832123e-05 / is equivalnet?  False
# Mixup / p-value:  3.131451951117439e-05 / is equivalnet?  False
# l2_0.001 / p-value:  0.00015183551583419918 / is equivalnet?  False
# l2_0.002 / p-value:  0.0013387584807080743 / is equivalnet?  False
# l2_0.004 / p-value:  0.012791761739201976 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 2500
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.01, 'seed': None}
# ----------
# ERM / p-value:  0.0031617965591035093 / is equivalnet?  False
# Mixup / p-value:  0.0397463227696987 / is equivalnet?  False
# l2_0.001 / p-value:  0.06720637148111233 / is equivalnet?  True
# l2_0.002 / p-value:  0.0617477749232943 / is equivalnet?  True
# l2_0.004 / p-value:  0.13898463774774927 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 5000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.01, 'seed': None}
# ----------
# ERM / p-value:  0.00015000167461815081 / is equivalnet?  False
# Mixup / p-value:  0.006228530593416397 / is equivalnet?  False
# l2_0.001 / p-value:  0.0034969970228080982 / is equivalnet?  False
# l2_0.002 / p-value:  0.09505225678032923 / is equivalnet?  True
# l2_0.004 / p-value:  0.026536193217925916 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 25000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.01, 'seed': None}
# ----------
# ERM / p-value:  3.9500343619282745e-09 / is equivalnet?  False
# Mixup / p-value:  0.00482769157480145 / is equivalnet?  False
# l2_0.001 / p-value:  0.007198006311116905 / is equivalnet?  False
# l2_0.002 / p-value:  0.002248230964028701 / is equivalnet?  False
# l2_0.004 / p-value:  0.00906143420475042 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 50000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.01, 'seed': None}
# ----------
# ERM / p-value:  4.286076106154522e-05 / is equivalnet?  False
# Mixup / p-value:  0.00016790795591771897 / is equivalnet?  False
# l2_0.001 / p-value:  0.001456519638579159 / is equivalnet?  False
# l2_0.002 / p-value:  0.0034232306671521384 / is equivalnet?  False
# l2_0.004 / p-value:  0.0038968093922747446 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 2500
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.02, 'seed': None}
# ----------
# ERM / p-value:  0.05621366119919395 / is equivalnet?  True
# Mixup / p-value:  0.614483374384643 / is equivalnet?  True
# l2_0.001 / p-value:  0.3442023653380299 / is equivalnet?  True
# l2_0.002 / p-value:  0.3369938359354126 / is equivalnet?  True
# l2_0.004 / p-value:  0.39831899209045696 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 5000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.02, 'seed': None}
# ----------
# ERM / p-value:  0.00013924571644720706 / is equivalnet?  False
# Mixup / p-value:  0.13278048189847452 / is equivalnet?  True
# l2_0.001 / p-value:  0.1633040357816695 / is equivalnet?  True
# l2_0.002 / p-value:  0.6341453749592536 / is equivalnet?  True
# l2_0.004 / p-value:  0.3239178704801932 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 25000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.02, 'seed': None}
# ----------
# ERM / p-value:  3.3359442825449055e-07 / is equivalnet?  False
# Mixup / p-value:  0.02587085914084983 / is equivalnet?  False
# l2_0.001 / p-value:  0.007583274270684429 / is equivalnet?  False
# l2_0.002 / p-value:  0.01816759840548861 / is equivalnet?  False
# l2_0.004 / p-value:  0.011779929693198096 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar10
# sample: 50000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.02, 'seed': None}
# ----------
# ERM / p-value:  3.853682392394417e-06 / is equivalnet?  False
# Mixup / p-value:  0.0004909939600263575 / is equivalnet?  False
# l2_0.001 / p-value:  0.013406815580903347 / is equivalnet?  False
# l2_0.002 / p-value:  0.012466622834560225 / is equivalnet?  False
# l2_0.004 / p-value:  0.04238113141072071 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True

# %% [markdown]
# ## CIFAR-100

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
print_summary_noise_table(dataset='cifar100', mode='gaussian', var=0.005)
print_summary_noise_table(dataset='cifar100', mode='gaussian', var=0.01)
print_summary_noise_table(dataset='cifar100', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 & $29.2\pm0.7$ & $27.6\pm1.7$ & $29.5\pm1.6$ & $30.8\pm1.4$ & $32.1\pm1.0$ & $33.4\pm1.1$ \tabularnewline
# & 5000 & $35.0\pm1.8$ & $34.7\pm1.8$ & $37.6\pm1.3$ & $39.9\pm0.8$ & $41.4\pm1.3$ & $42.2\pm0.9$ \tabularnewline
# & 25000 & $43.1\pm1.4$ & $48.3\pm1.1$ & $54.3\pm0.6$ & $56.5\pm1.1$ & $58.5\pm0.4$ & $59.8\pm0.4$ \tabularnewline
# & 50000 & $46.0\pm0.9$ & $50.6\pm1.4$ & $59.3\pm0.8$ & $61.1\pm0.6$ & $63.5\pm0.6$ & $65.2\pm0.4$ \tab\hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 & $25.3\pm1.3$ & $23.0\pm1.8$ & $24.5\pm1.5$ & $25.7\pm1.5$ & $26.6\pm1.1$ & $28.2\pm1.4$ \tabularnewline
# & 5000 & $27.7\pm2.3$ & $27.2\pm2.4$ & $29.6\pm1.5$ & $31.7\pm0.8$ & $33.8\pm1.4$ & $35.2\pm1.2$ \tabularnewline
# & 25000 & $30.6\pm1.3$ & $34.2\pm1.2$ & $39.9\pm1.7$ & $43.5\pm1.7$ & $47.0\pm0.6$ & $49.9\pm0.6$ \tabularnewline
# & 50000 & $31.3\pm1.0$ & $35.5\pm2.4$ & $44.0\pm1.0$ & $46.9\pm0.8$ & $50.9\pm1.2$ & $54.4\pm1.1$ \tab\hline
# \end{tabular}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \hline
# Dataset & Sample size & erm & mixup & l2-0.001 & l2-0.002 & l2-0.004 & l2-0.008\tabularnewline
# \hline
# \hline
# \multirow{5}{*}{cifar100}
# & 2500 & $19.6\pm1.7$ & $18.3\pm1.8$ & $19.3\pm1.1$ & $19.9\pm1.8$ & $20.6\pm1.1$ & $21.7\pm1.2$ \tabularnewline
# & 5000 & $19.2\pm2.5$ & $18.7\pm2.1$ & $21.0\pm1.3$ & $22.4\pm0.6$ & $24.2\pm1.5$ & $25.2\pm1.7$ \tabularnewline
# & 25000 & $18.1\pm1.5$ & $19.8\pm1.4$ & $24.1\pm2.5$ & $27.1\pm1.9$ & $31.0\pm1.1$ & $33.4\pm1.6$ \tabularnewline
# & 50000 & $17.2\pm1.0$ & $19.9\pm2.3$ & $25.8\pm1.8$ & $28.3\pm0.6$ & $32.1\pm1.3$ & $37.1\pm1.3$ \tab\hline
# \end{tabular}

# %%
print_t_test_noise_results(dataset='cifar100', mode='gaussian', var=0.005)
print_t_test_noise_results(dataset='cifar100', mode='gaussian', var=0.01)
print_t_test_noise_results(dataset='cifar100', mode='gaussian', var=0.02)
# Out:
# ----------
# dataset: cifar100
# sample: 2500
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.005, 'seed': None}
# ----------
# ERM / p-value:  0.0002937474362159686 / is equivalnet?  False
# Mixup / p-value:  0.00035999552596110567 / is equivalnet?  False
# l2_0.001 / p-value:  0.0027660032088842666 / is equivalnet?  False
# l2_0.002 / p-value:  0.013342075065213897 / is equivalnet?  False
# l2_0.004 / p-value:  0.09533895244726612 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 5000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.005, 'seed': None}
# ----------
# ERM / p-value:  0.00020812627937342364 / is equivalnet?  False
# Mixup / p-value:  0.00016779116802535918 / is equivalnet?  False
# l2_0.001 / p-value:  0.00024207691611928935 / is equivalnet?  False
# l2_0.002 / p-value:  0.0030383371184429437 / is equivalnet?  False
# l2_0.004 / p-value:  0.2846119101643464 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 25000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.005, 'seed': None}
# ----------
# ERM / p-value:  2.9546935895687625e-06 / is equivalnet?  False
# Mixup / p-value:  2.100917496128951e-06 / is equivalnet?  False
# l2_0.001 / p-value:  4.054826265250057e-07 / is equivalnet?  False
# l2_0.002 / p-value:  0.001147384159538465 / is equivalnet?  False
# l2_0.004 / p-value:  0.0009110978284113775 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 50000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.005, 'seed': None}
# ----------
# ERM / p-value:  4.382165729289965e-08 / is equivalnet?  False
# Mixup / p-value:  9.350475494434258e-06 / is equivalnet?  False
# l2_0.001 / p-value:  1.404075191112134e-05 / is equivalnet?  False
# l2_0.002 / p-value:  1.0949466478040858e-05 / is equivalnet?  False
# l2_0.004 / p-value:  0.0009112793326268083 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 2500
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.01, 'seed': None}
# ----------
# ERM / p-value:  0.009069192926902904 / is equivalnet?  False
# Mixup / p-value:  0.001308339226850675 / is equivalnet?  False
# l2_0.001 / p-value:  0.00429372371873886 / is equivalnet?  False
# l2_0.002 / p-value:  0.027545791159638 / is equivalnet?  False
# l2_0.004 / p-value:  0.08724235561863394 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 5000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.01, 'seed': None}
# ----------
# ERM / p-value:  0.0006471890634000962 / is equivalnet?  False
# Mixup / p-value:  0.0005547159448417807 / is equivalnet?  False
# l2_0.001 / p-value:  0.0002464658290392189 / is equivalnet?  False
# l2_0.002 / p-value:  0.0009145099107270308 / is equivalnet?  False
# l2_0.004 / p-value:  0.13131495347315023 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 25000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.01, 'seed': None}
# ----------
# ERM / p-value:  1.0086079261128841e-07 / is equivalnet?  False
# Mixup / p-value:  1.3108774605952632e-07 / is equivalnet?  False
# l2_0.001 / p-value:  4.640581589105342e-05 / is equivalnet?  False
# l2_0.002 / p-value:  0.0004460218040755548 / is equivalnet?  False
# l2_0.004 / p-value:  8.238072033809784e-05 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 50000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.01, 'seed': None}
# ----------
# ERM / p-value:  4.811143038527627e-10 / is equivalnet?  False
# Mixup / p-value:  7.191961358062387e-06 / is equivalnet?  False
# l2_0.001 / p-value:  2.5864549921171645e-07 / is equivalnet?  False
# l2_0.002 / p-value:  3.133486408447432e-06 / is equivalnet?  False
# l2_0.004 / p-value:  0.0013932832935096564 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 2500
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.02, 'seed': None}
# ----------
# ERM / p-value:  0.05544904079126242 / is equivalnet?  True
# Mixup / p-value:  0.009738572829733236 / is equivalnet?  False
# l2_0.001 / p-value:  0.010869921758470505 / is equivalnet?  False
# l2_0.002 / p-value:  0.10543635798121376 / is equivalnet?  True
# l2_0.004 / p-value:  0.1598501646540611 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 5000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.02, 'seed': None}
# ----------
# ERM / p-value:  0.0027362499982002807 / is equivalnet?  False
# Mixup / p-value:  0.0007887433012713789 / is equivalnet?  False
# l2_0.001 / p-value:  0.002406429240004583 / is equivalnet?  False
# l2_0.002 / p-value:  0.016101272334447983 / is equivalnet?  False
# l2_0.004 / p-value:  0.3238993198106739 / is equivalnet?  True
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 25000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.02, 'seed': None}
# ----------
# ERM / p-value:  2.732999109892074e-07 / is equivalnet?  False
# Mixup / p-value:  5.391511720817789e-07 / is equivalnet?  False
# l2_0.001 / p-value:  0.0002595241700117868 / is equivalnet?  False
# l2_0.002 / p-value:  0.0005674042259592803 / is equivalnet?  False
# l2_0.004 / p-value:  0.023308170272605757 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True
# ----------
# dataset: cifar100
# sample: 50000
# noise: {'Mode': 'Gaussian', 'Mean': 0, 'Var': 0.02, 'seed': None}
# ----------
# ERM / p-value:  1.2113529227103096e-08 / is equivalnet?  False
# Mixup / p-value:  3.776032242952221e-06 / is equivalnet?  False
# l2_0.001 / p-value:  6.209461590631091e-06 / is equivalnet?  False
# l2_0.002 / p-value:  2.0778611237314327e-05 / is equivalnet?  False
# l2_0.004 / p-value:  0.0002993463527508855 / is equivalnet?  False
# l2_0.008 / p-value:  1.0 / is equivalnet?  True

# %% [markdown]
# # Visualize results
# ## CIFAR-10

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
show_noise_plot(dataset='cifar10', split='test', mode='gaussian', var=0.005)
show_noise_plot(dataset='cifar10', split='test', mode='gaussian', var=0.01)
show_noise_plot(dataset='cifar10', split='test', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------

# %% [markdown]
# ## CIFAR-100

# %%
print('-'*30)
print('Gaussian')
print('-'*30)
show_noise_plot(dataset='cifar100', split='test', mode='gaussian', var=0.005)
show_noise_plot(dataset='cifar100', split='test', mode='gaussian', var=0.01)
show_noise_plot(dataset='cifar100', split='test', mode='gaussian', var=0.02)
# Out:
# ------------------------------
# Gaussian
# ------------------------------
